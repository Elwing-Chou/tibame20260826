# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260826/blob/main/tibame20260923.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req

url = "https://github.com/Elwing-Chou/tibame20260826/raw/refs/heads/main/total.csv"
req.urlretrieve(url, "total.csv")
# Out:
# ('total.csv', <http.client.HTTPMessage at 0x7ae0bc7e10f0>)

# %%
import pandas as pd
df = pd.read_csv("total.csv", encoding="utf-8")
df
# Out:
#                     text    color  size  position   time     sn       userid
# 0                      簽  #A7FE39     1         0      0  30997     k9219059
# 1      2022.8.22第一個 耶～～😋  #FF02D3     2         0      2  30997  Amy20080403
# 2                      👌  #FFFFFF     1         0     10  30997      winolee
# 3             一集接一集停不下來～  #FFFFFF     1         0     35  30997  eggplant171
# 4           前面的，你每集都出現耶😂  #FFFFFF     1         0     37  30997  love3769846
# ...                  ...      ...   ...       ...    ...    ...          ...
# 36001              兩個大胸鬼  #FFFFFF     1         0  12939  30996       aaidjd
# 36002     龍顯蕙聲線真的很適合妖媚的鬼  #FFFFFF     1         0  13130  30996  eggplant171
# 36003               玟次郎？  #FDE53D     2         2  13855  30996      lpx1007
# 36004            戳爆他的泡泡！  #FFFFFF     1         0  13938  30996      LWT1109
# 36005    別把他弄醒了，睡著時比較可靠呀  #FFFFFF     1         0  13958  30996      gamefan
#
# [36006 rows x 7 columns]
