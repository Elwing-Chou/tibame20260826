# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260826/blob/main/tibame20260831.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print2line():
    for j in range(2):
        print("hello")

for i in range(3):
    print(i+1)
    print2line()

# %%
# 1
# hello
# hello
# 2
# hello
# hello
for i in range(3):
    print(i+1)
    for j in range(2):
        print("hello")
