# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260826/blob/main/tibame20260826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5

# %% [markdown]
# - 進階知識
#     - Latex Math語法: \ {}
#     - $ area = \frac{1}{1+x} \pi R^3 $
# - https://github.com/Elwing-Chou/tibame20260826

# %% [markdown]
# - LAB 1. 完全平方日
#     - 20150304 = 4489 x 4489
#     - 20241001 = 4499 x 4499
#     - 題目: 給你一個日期, 你要往後數出接下來的10個完全平方日的日期
#         - 作法1: 我一個一個日期數下去, 找到十個
#             - 20241001^0.5->4499(O)
#             - 20241001^0.5->4499.0001(X)
#         - 作法2: 我一個一個數字, 做平方數下去, 找到十個
#             - 4499 x 4499 -> 20241001(O)
#             - 4500 x 4500 -> 20250000(X)
#         - 作法1.
#             - 20150304->20241001 10年x365-> 3650個日期
#         - 作法2.
#             - 4489 -> 4499 -> 11個
#         - 作法2會比較好, 而且可能比做法1快上100~1000倍
#         - 以後只要看到這種有^2 ^3 ^4..., 你都要從做法2的角度看
#     - 要把想法1和想法2都實做出來, 然後真的比較他的執行速度
#     - 想法2.
#         - 我應該要有個迴圈(直到找到10個停)
#         - 平方, 確認是否為一個日期
#             - 年: >= 1
#             - 月: 12~1
#             - 日:
#                 - 每個月不一樣
#                 - 閏年
